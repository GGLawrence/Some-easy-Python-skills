# %% [markdown]
# # Code Method

# %%
from IPython.display import Image

# Specify the path to your image file
image_path = "Figure1.png"

# Display the image in the Jupyter Notebook
Image(filename=image_path)

# %% [markdown]
# # Markdown Method
# ### In Markdown environment, use the following code.

# %%
"""
<div style="text-align:center">
    <img src="Figure1.png" alt="Image" width="400"/>
</div>
"""
# Out:
# '\n<div style="text-align:center">\n    <img src="Figure1.png" alt="Image" width="400"/>\n</div>\n'

# %% [markdown]
# <div style="text-align:center">
#     <img src="Figure1.png" alt="Image" width="400"/>
# </div>
